# %%
# !pip install python-louvain
# !pip install eagerpy
# !pip install gudhi
# !pip install pot
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.12/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from python-louvain) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from python-louvain) (2.0.2)
# Requirement already satisfied: eagerpy in /usr/local/lib/python3.12/dist-packages (0.30.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from eagerpy) (2.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.12/dist-packages (from eagerpy) (4.15.0)
# Requirement already satisfied: gudhi in /usr/local/lib/python3.12/dist-packages (3.11.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from gudhi) (2.0.2)
# Requirement already satisfied: pot in /usr/local/lib/python3.12/dist-packages (0.9.6.post1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.12/dist-packages (from pot) (2.0.2)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.12/dist-packages (from pot) (1.16.3)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
import math
import time
import random
import networkx as nx
from itertools import combinations
from sklearn.preprocessing import OneHotEncoder
from matplotlib import pyplot as plt
import copy
from community import community_louvain
import umap
from sklearn.manifold import TSNE
import scipy.sparse as sp
from itertools import combinations
import networkx as nx
import seaborn as sn
from sklearn.cluster import KMeans
import gudhi as gd
from gudhi.wasserstein import wasserstein_distance

# %%
class Args():
    def __init__(self) -> None:
        self.dataset = 'cora'
        self.model = 'GAE'

        self.input_dim = 200
        self.encoded_space_dim = 50
        self.n_cluster = 5
        self.use_feature = False

        self.num_epoch = 500
        self.learning_rate = 0.01
        self.start_mf = 300
        self.LAMBDA = 0.01
args = Args()

# %%
def visualize_tsne(epoch_idx, features, point_color="k", cluster_centers=None):
    tsne_model = TSNE(
        n_components=2,
        random_state=33,
        init="pca",
        learning_rate="auto"
    )

    if cluster_centers is not None:
        combined_data = np.concatenate([features, cluster_centers], axis=0)
        projected = tsne_model.fit_transform(combined_data)

        center_proj = projected[-len(cluster_centers):]
        data_proj = projected[:-len(cluster_centers)]
    else:
        data_proj = tsne_model.fit_transform(features)

    plt.figure(figsize=(25, 25))
    plt.scatter(data_proj[:, 0], data_proj[:, 1], c=point_color, s=20)

    if cluster_centers is not None:
        plt.scatter(center_proj[:, 0], center_proj[:, 1], c="k", marker="*")

    plt.title("TSNE projection of the dataset")
    plt.show()


def visualize_umap(epoch_idx, features, point_color="k", cluster_centers=None):
    umap_model = umap.UMAP(random_state=42)

    data_proj = umap_model.fit_transform(features)

    plt.figure(figsize=(5, 5))
    plt.scatter(data_proj[:, 0], data_proj[:, 1], c=point_color, s=20)

    if cluster_centers is not None:
        center_proj = umap_model.transform(cluster_centers)
        plt.scatter(center_proj[:, 0], center_proj[:, 1], c="k", marker="*")

    plt.title("UMAP projection of the dataset")
    plt.show()

# %%
def decode_by_inner_product(latent_z):
    similarity = torch.matmul(latent_z, latent_z.transpose(0, 1))
    return torch.sigmoid(similarity)


def glorot_parameter(in_dim, out_dim):
    limit = np.sqrt(6.0 / (in_dim + out_dim))
    weight_tensor = torch.empty(in_dim, out_dim).uniform_(-limit, limit)
    return nn.Parameter(weight_tensor, requires_grad=True)

# %%
class SparseGraphConvolution(nn.Module):
    def __init__(self, in_features, out_features, adjacency, nonlinearity=F.leaky_relu):
        super().__init__()
        self.W = glorot_parameter(in_features, out_features)
        self.adjacency = adjacency
        self.nonlinearity = nonlinearity

    def forward(self, node_features):
        support = torch.mm(node_features, self.W)
        aggregated = torch.mm(self.adjacency, support)
        return self.nonlinearity(aggregated)

# %%
class GraphAutoEncoder(nn.Module):
    def __init__(self, adjacency):
        super().__init__()

        self.encoder_layer = SparseGraphConvolution(
            args.input_dim,
            args.encoded_space_dim,
            adjacency
        )

        self.centroids = glorot_parameter(
            args.n_cluster,
            args.encoded_space_dim
        )

    @staticmethod
    def row_normalize(matrix):
        min_vals = matrix.min(dim=1).values.unsqueeze(1)
        max_vals = matrix.max(dim=1).values.unsqueeze(1)
        scaled = (matrix - min_vals) / (max_vals - min_vals)
        return scaled / torch.sum(scaled, dim=1, keepdim=True)

    def encode(self, features):
        latent = self.encoder_layer(features)
        latent = F.normalize(latent, p=2, dim=1)
        return latent

    def forward(self, inputs, epoch_idx):
        z = self.encode(inputs)

        adjacency_hat = decode_by_inner_product(z)

        if epoch_idx > args.start_mf:
            centroid_pinv = torch.linalg.pinv(self.centroids)
            assignment = self.row_normalize(torch.mm(z, centroid_pinv))
            return adjacency_hat, z, assignment

        return adjacency_hat, z, None

# %%
def convert_sparse_matrix(matrix):
    if not sp.isspmatrix_coo(matrix):
        matrix = matrix.tocoo()

    indices = np.stack((matrix.row, matrix.col), axis=1)
    data = matrix.data
    dims = matrix.shape

    return indices, data, dims


def normalize_adjacency(adj_matrix):
    adj_coo = sp.coo_matrix(adj_matrix)

    identity = sp.eye(adj_coo.shape[0])
    adj_self_loop = adj_coo + identity

    degree = np.array(adj_self_loop.sum(axis=1))
    deg_inv_sqrt = np.power(degree, -0.5).flatten()
    deg_inv_sqrt_mat = sp.diags(deg_inv_sqrt)

    normalized_adj = (
        adj_self_loop
        .dot(deg_inv_sqrt_mat)
        .transpose()
        .dot(deg_inv_sqrt_mat)
        .tocoo()
    )

    return convert_sparse_matrix(normalized_adj)

# %%
# Generate synthetic graph with community structure
graph = nx.gaussian_random_partition_graph(
    n=200,
    s=40,
    v=40,
    p_in=0.5,
    p_out=0.001
)

# Extract ground-truth partition information
gt_partition = graph.graph["partition"]
node_groups = np.concatenate(
    [[idx] * len(nodes) for idx, nodes in enumerate(gt_partition)],
    axis=0
)

# Compute layout (copy used to avoid side effects)
layout_graph = graph.copy()
pos = nx.spring_layout(layout_graph, seed=17)
del layout_graph

# Visualization
plt.figure(figsize=(16,16))
nx.draw(
    graph,
    pos,
    node_color=node_groups,
    node_size=10,
    edge_color="gray"
)
plt.show()

# %%
# Build sparse adjacency matrix from NetworkX graph
adjacency_sparse = sp.coo_matrix(nx.adjacency_matrix(graph))

# Create identity feature matrix (one-hot encoding per node)
identity_features = sp.eye(adjacency_sparse.shape[0], dtype=np.int64).tocoo()

# Convert sparse matrix to tuple representation
feat_indices, feat_values, feat_shape = convert_sparse_matrix(identity_features)


# Construct PyTorch sparse tensor
node_features = torch.sparse.FloatTensor(
    torch.LongTensor(feat_indices.T),
    torch.FloatTensor(feat_values),
    torch.Size(feat_shape)
)
# Out:
# /tmp/ipython-input-356956039.py:12: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:654.)
#   node_features = torch.sparse.FloatTensor(

# %%
def compute_louvain_partition(graph):
    partition = community_louvain.best_partition(
        graph,
        weight="weight"
    )
    return partition


louvain_partition = compute_louvain_partition(graph)

# %%
def visualize_louvain(graph, partition):
    node_colors = [0] * len(partition)

    idx = 0
    for _, community_id in partition.items():
        node_colors[idx] = community_id
        idx += 1

    layout = nx.spring_layout(graph)
    nx.draw(
        graph,
        layout,
        with_labels=False,
        node_size=70,
        width=0.5,
        node_color=node_colors
    )
    plt.show()


visualize_louvain(graph, louvain_partition)

# %%
def evaluate_clustering_results(cluster_assignments, true_labels, n_clusters=10):
    label_cluster_pairs = np.dstack([true_labels, cluster_assignments])[0]

    confusion_counts = np.zeros((n_clusters, n_clusters), dtype=int)
    for i in range(len(label_cluster_pairs)):
        confusion_counts[
            label_cluster_pairs[i][1],
            label_cluster_pairs[i][0]
        ] += 1

    cluster_to_label_map = list(map(lambda row: np.argmax(row), confusion_counts))
    confusion_counts = sorted(confusion_counts, key=lambda row: np.argmax(row))

    fig, ax = plt.subplots(1, figsize=(5, 5))
    heatmap = sn.heatmap(
        confusion_counts,
        annot=True,
        fmt="d",
        annot_kws={"size": 10},
        cmap="coolwarm",
        ax=ax,
        square=True,
        yticklabels=cluster_to_label_map
    )

    plt.xlabel("Actual")
    plt.ylabel("Cluster")
    heatmap.tick_params(length=0)
    heatmap.xaxis.tick_top()
    heatmap.xaxis.set_label_position("top")
    plt.title("Cluster match count for each number")

    # Purity calculation
    purity_counter = np.zeros((n_clusters, 1))

    for i in range(len(label_cluster_pairs)):
        if cluster_to_label_map[label_cluster_pairs[i][1]] == true_labels[i]:
            purity_counter[
                cluster_to_label_map[label_cluster_pairs[i][0]]
            ] += 1

    purity_score = np.add.reduce(purity_counter)[0] / len(true_labels)
    print("Purity", purity_score)

    plt.show()

# %%
def run_kmeans_evaluation(latent_embeddings, true_labels, soft_assignments, n_clusters=7):
    kmeans_model = KMeans(n_clusters=n_clusters)

    z_cpu = latent_embeddings.cpu().detach()
    kmeans_model.fit(z_cpu)

    evaluate_clustering_results(
        kmeans_model.labels_,
        true_labels,
        n_clusters=n_clusters
    )

    evaluate_clustering_results(
        soft_assignments.argmax(axis=1).cpu().detach(),
        true_labels,
        n_clusters=n_clusters
    )

# %%
def compute_accuracy(reconstructed_adj, true_adj):
    true_labels = true_adj.to_dense().view(-1).long()
    predicted_labels = (reconstructed_adj > 0.5).view(-1).long()
    return (predicted_labels == true_labels).sum().float() / true_labels.size(0)

# %%
############################
# Vietoris–Rips filtration #
############################

def compute_wrcf_filtration(graph: nx.Graph, weight="weight"):
    """
    Compute the weight-rank clique filtration (WRCF) of a graph.

    :param graph: networkx Graph
    :param weight: edge weight attribute name
    :return: gudhi SimplexTree
    """
    simplex_tree = gd.SimplexTree()

    # Filtration step 0: insert all vertices
    for node in graph.nodes():
        simplex_tree.insert([node], filtration=0)

    # Sort unique edge weights (descending)
    ranked_weights = np.unique(
        [w for _, _, w in graph.edges.data(weight)]
    )[::-1]

    for _, threshold in enumerate(ranked_weights):
        # Threshold graph
        filtered_edges = [
            (u, v) for u, v, w in graph.edges.data(weight) if w >= threshold
        ]
        subgraph = graph.edge_subgraph(filtered_edges)

        # Insert maximal cliques
        for clique in nx.find_cliques(subgraph):
            # simplex_tree.insert(clique, filtration=_ + 1)  # thesis version
            simplex_tree.insert(clique, filtration=1 / threshold)

    return simplex_tree


def compute_wrcf_indices(adjacency_matrix, homology_dim, cardinality):
    """
    Parameters:
        adjacency_matrix : numpy array
        homology_dim     : homological dimension
        cardinality      : number of persistence pairs
    """

    simplex_tree = compute_wrcf_filtration(
      nx.from_numpy_array(adjacency_matrix)
    )

    _ = simplex_tree.persistence()
    persistence_pairs = simplex_tree.persistence_pairs()

    selected_indices = []
    persistence_values = []

    for birth_simplex, death_simplex in persistence_pairs:
        if len(birth_simplex) == homology_dim + 1 and len(death_simplex) > 0:
            birth_vertices = np.array(birth_simplex)
            death_vertices = np.array(death_simplex)

            birth_pair = np.unravel_index(
                np.argmax(adjacency_matrix[birth_vertices][:, birth_vertices]),
                (len(birth_simplex), len(birth_simplex))
            )
            death_pair = np.unravel_index(
                np.argmax(adjacency_matrix[death_vertices][:, death_vertices]),
                (len(death_simplex), len(death_simplex))
            )

            selected_indices += [birth_simplex[birth_pair[0]], birth_simplex[birth_pair[1]]]
            selected_indices += [death_simplex[death_pair[0]], death_simplex[death_pair[1]]]

            persistence_values.append(
                simplex_tree.filtration(death_simplex)
                - simplex_tree.filtration(birth_simplex)
            )

    # Sort by persistence (distance to diagonal)
    order = np.argsort(persistence_values)
    selected_indices = (
        np.reshape(selected_indices, [-1, 4])[order][::-1].flatten().tolist()
    )

    # Pad if needed
    target_length = 4 * cardinality
    selected_indices = selected_indices[:target_length] + \
        [0] * max(0, target_length - len(selected_indices))

    return np.array(selected_indices, dtype=np.int32)


class WRCFLayer(torch.nn.Module):
    def __init__(self, dim=1, card=50):
        super(WRCFLayer, self).__init__()
        self.dim = dim
        self.card = card

    def forward(self, adjacency_tensor: torch.Tensor):
        homology_dim = self.dim
        cardinality = self.card

        with torch.no_grad():
            vertex_indices = torch.from_numpy(
                compute_wrcf_indices(
                    adjacency_tensor.cpu().numpy(),
                    homology_dim,
                    cardinality
                )
            )

        if homology_dim > 0:
            index_pairs = vertex_indices.view(2 * cardinality, 2).long()
            persistence_diagram = adjacency_tensor[
                index_pairs[:, 0], index_pairs[:, 1]
            ].view(cardinality, 2)
        else:
            index_pairs = vertex_indices.view(2 * cardinality, 2)[1::2].long()
            persistence_diagram = torch.cat(
                [
                    torch.zeros(cardinality, 1),
                    adjacency_tensor[
                        index_pairs[:, 0], index_pairs[:, 1]
                    ].view(cardinality, 1).float()
                ],
                dim=1
            )

        return persistence_diagram

# %%
class WrcfGAE(torch.nn.Module):
    def __init__(self, adjacency_sparse, gae_model, ground_truth) -> None:
        super().__init__()

        # GAE model (frozen / CPU for topology)
        self.gae = gae_model.cpu()

        # WRCF layer
        self.wrcf = WRCFLayer(dim=0, card=20)

        # Sparse adjacency (scipy COO)
        self.adjacency_sparse = adjacency_sparse

        # Ground-truth persistence diagram
        self.Q = None
        self.dgm_gt = self.wrcf(
            self.build_community_graph(*ground_truth)
        )

    @staticmethod
    def soft_argmax(x, dim, beta=1e2):
        # crude: assumes max value is unique
        scaled = beta * x
        probs = torch.nn.functional.softmax(scaled, dim=dim)
        indices = torch.arange(x.size(dim), device=x.device)
        weighted = indices * probs
        return torch.sum(weighted, dim=dim)

    def build_community_graph(self, soft_assignments: torch.Tensor, adjacency_sparse):
        """
        soft_assignments : (N × K) indicator matrix
        adjacency_sparse : scipy.sparse COO adjacency
        """
        # Hard assignment
        indicator = torch.argmax(soft_assignments, dim=1)

        indicator_hat = torch.stack(
            [
                torch.where(indicator == k, 1.0, 0.0)
                for k in range(soft_assignments.size(1))
            ]
        ).T

        Q_hat = indicator_hat * soft_assignments

        W_dense = torch.tensor(
            adjacency_sparse.todense(),
            dtype=torch.float
        )

        community_graph = torch.mm(
            torch.mm(Q_hat.T, W_dense),
            Q_hat
        ).fill_diagonal_(0)

        # Normalization
        community_graph = community_graph / W_dense.sum()

        return community_graph

    def forward(self, node_features, epoch, adj_label, weight_tensor, norm):

        reconstructed_adj, latent_embeddings, soft_assignments = self.gae(
            node_features, epoch + args.start_mf + 1
        )

        reconstruction_loss = norm * F.binary_cross_entropy(
            reconstructed_adj.view(-1),
            adj_label.to_dense().view(-1),
            weight=weight_tensor
        )

        mse_loss = torch.nn.MSELoss()
        clustering_loss = mse_loss(
            latent_embeddings,
            torch.mm(soft_assignments, self.gae.centroids)
        )

        # Topological loss via WRCF
        community_graph = self.build_community_graph(
            soft_assignments,
            self.adjacency_sparse
        )

        dgm_community = self.wrcf(community_graph)

        wasserstein_dist = wasserstein_distance(
            self.dgm_gt.detach().numpy(),
            dgm_community.detach().numpy(),
            order=1,
            internal_p=2
        )
        topological_loss = torch.tensor(wasserstein_dist, dtype=torch.float)

        total_loss = reconstruction_loss + clustering_loss + topological_loss

        return total_loss, reconstructed_adj, latent_embeddings, soft_assignments

# %%
def train_model(node_features, adjacency_sparse):
    # Normalize adjacency
    adj_norm_tuple = normalize_adjacency(adjacency_sparse)
    adj_label_tuple = convert_sparse_matrix(adjacency_sparse)

    adj_norm = torch.sparse.FloatTensor(
        torch.LongTensor(adj_norm_tuple[0].T),
        torch.FloatTensor(adj_norm_tuple[1]),
        torch.Size(adj_norm_tuple[2])
    )

    adj_label = torch.sparse.FloatTensor(
        torch.LongTensor(adj_label_tuple[0].T),
        torch.FloatTensor(adj_label_tuple[1]),
        torch.Size(adj_label_tuple[2])
    )

    # Class imbalance handling
    positive_weight = float(
        adjacency_sparse.shape[0] * adjacency_sparse.shape[0] - adjacency_sparse.sum()
    ) / adjacency_sparse.sum()

    normalization_factor = (
        adjacency_sparse.shape[0] * adjacency_sparse.shape[0] /
        float((adjacency_sparse.shape[0] * adjacency_sparse.shape[0] - adjacency_sparse.sum()) * 2)
    )

    label_mask = adj_label.to_dense().view(-1) == 1
    loss_weights = torch.ones(label_mask.size(0))
    loss_weights[label_mask] = positive_weight

    # Convert node_groups to one-hot encoding for ground truth soft assignments
    num_nodes = len(node_groups)
    num_clusters = args.n_cluster # This should be correctly set by the calling cell
    one_hot_node_groups = torch.zeros(num_nodes, num_clusters)
    one_hot_node_groups[torch.arange(num_nodes), torch.tensor(node_groups)] = 1.0

    # Initialize model
    gae_model = GraphAutoEncoder(adj_norm)
    model = WrcfGAE(adjacency_sparse, gae_model, (one_hot_node_groups, adjacency_sparse))
    optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate)

    # Training loop
    for epoch_idx in range(args.num_epoch):
        start_time = time.time()

        total_loss, reconstructed_adj, latent_embeddings, soft_assignments = model(
            node_features, epoch_idx, adj_label, loss_weights, normalization_factor
        )

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        train_accuracy = compute_accuracy(reconstructed_adj, adj_label)

        print(
            "Epoch:", f"{epoch_idx + 1:04d}",
            "train_loss=", f"{total_loss.item():.5f}",
            "train_acc=", f"{train_accuracy:.5f}",
            "time=", f"{time.time() - start_time:.5f}"
        )

    run_kmeans_evaluation(
        latent_embeddings,
        true_labels=clusters,
        soft_assignments=soft_assignments,
        n_clusters=args.n_cluster
    )

    return model

# %%
args.n_cluster = len(np.unique(node_groups))
clusters = node_groups
model = train_model(node_features, adjacency_sparse)
# Out:
# Epoch: 0001 train_loss= 0.69466 train_acc= 0.09305 time= 0.02841
# Epoch: 0002 train_loss= 0.63373 train_acc= 0.09780 time= 0.02555
# Epoch: 0003 train_loss= 0.59646 train_acc= 0.19710 time= 0.01829
# Epoch: 0004 train_loss= 0.57917 train_acc= 0.35715 time= 0.01470
# Epoch: 0005 train_loss= 0.56988 train_acc= 0.48800 time= 0.01486
# Epoch: 0006 train_loss= 0.56256 train_acc= 0.61330 time= 0.01551
# Epoch: 0007 train_loss= 0.55886 train_acc= 0.73730 time= 0.01530
# Epoch: 0008 train_loss= 0.55640 train_acc= 0.81650 time= 0.01450
# Epoch: 0009 train_loss= 0.55482 train_acc= 0.84645 time= 0.01586
# Epoch: 0010 train_loss= 0.55369 train_acc= 0.85980 time= 0.01563
# Epoch: 0011 train_loss= 0.55287 train_acc= 0.86960 time= 0.01746
# Epoch: 0012 train_loss= 0.55136 train_acc= 0.87080 time= 0.01577
# Epoch: 0013 train_loss= 0.55091 train_acc= 0.87150 time= 0.01490
# Epoch: 0014 train_loss= 0.55032 train_acc= 0.87570 time= 0.01737
# Epoch: 0015 train_loss= 0.55012 train_acc= 0.87980 time= 0.01446
# Epoch: 0016 train_loss= 0.54952 train_acc= 0.87990 time= 0.01462
# Epoch: 0017 train_loss= 0.54895 train_acc= 0.88060 time= 0.01427
# Epoch: 0018 train_loss= 0.54847 train_acc= 0.88520 time= 0.01427
# Epoch: 0019 train_loss= 0.54795 train_acc= 0.88870 time= 0.01575
# Epoch: 0020 train_loss= 0.54746 train_acc= 0.89120 time= 0.01468
# Epoch: 0021 train_loss= 0.54700 train_acc= 0.89120 time= 0.01463
# Epoch: 0022 train_loss= 0.54678 train_acc= 0.89120 time= 0.01429
# Epoch: 0023 train_loss= 0.54635 train_acc= 0.89120 time= 0.01439
# Epoch: 0024 train_loss= 0.54594 train_acc= 0.89250 time= 0.01479
# Epoch: 0025 train_loss= 0.54554 train_acc= 0.89510 time= 0.01501
# Epoch: 0026 train_loss= 0.54515 train_acc= 0.89510 time= 0.01427
# Epoch: 0027 train_loss= 0.54476 train_acc= 0.89510 time= 0.01626
# Epoch: 0028 train_loss= 0.54436 train_acc= 0.89510 time= 0.01968
# Epoch: 0029 train_loss= 0.54397 train_acc= 0.89510 time= 0.01830
# Epoch: 0030 train_loss= 0.54356 train_acc= 0.89520 time= 0.02098
# Epoch: 0031 train_loss= 0.54316 train_acc= 0.89670 time= 0.01687
# Epoch: 0032 train_loss= 0.54277 train_acc= 0.89890 time= 0.01629
# Epoch: 0033 train_loss= 0.54238 train_acc= 0.89890 time= 0.02071
# Epoch: 0034 train_loss= 0.54200 train_acc= 0.89890 time= 0.01827
# Epoch: 0035 train_loss= 0.54163 train_acc= 0.89890 time= 0.01877
# Epoch: 0036 train_loss= 0.54127 train_acc= 0.89890 time= 0.01612
# Epoch: 0037 train_loss= 0.54092 train_acc= 0.89890 time= 0.01563
# Epoch: 0038 train_loss= 0.54058 train_acc= 0.89890 time= 0.01572
# Epoch: 0039 train_loss= 0.54024 train_acc= 0.89890 time= 0.01296
# Epoch: 0040 train_loss= 0.53991 train_acc= 0.89890 time= 0.01330
# Epoch: 0041 train_loss= 0.53960 train_acc= 0.89890 time= 0.01029
# Epoch: 0042 train_loss= 0.53930 train_acc= 0.89890 time= 0.01001
# Epoch: 0043 train_loss= 0.53901 train_acc= 0.89890 time= 0.00973
# Epoch: 0044 train_loss= 0.53873 train_acc= 0.89890 time= 0.00975
# Epoch: 0045 train_loss= 0.53847 train_acc= 0.89890 time= 0.00988
# Epoch: 0046 train_loss= 0.53822 train_acc= 0.89890 time= 0.01063
# Epoch: 0047 train_loss= 0.53797 train_acc= 0.89890 time= 0.00992
# Epoch: 0048 train_loss= 0.53772 train_acc= 0.89890 time= 0.00971
# Epoch: 0049 train_loss= 0.53747 train_acc= 0.89890 time= 0.01115
# Epoch: 0050 train_loss= 0.53723 train_acc= 0.89890 time= 0.01001
# Epoch: 0051 train_loss= 0.53698 train_acc= 0.89890 time= 0.01148
# Epoch: 0052 train_loss= 0.53674 train_acc= 0.89890 time= 0.00998
# Epoch: 0053 train_loss= 0.53649 train_acc= 0.89890 time= 0.01073
# Epoch: 0054 train_loss= 0.53624 train_acc= 0.89890 time= 0.00974
# Epoch: 0055 train_loss= 0.53599 train_acc= 0.89890 time= 0.01044
# Epoch: 0056 train_loss= 0.53572 train_acc= 0.89890 time= 0.01231
# Epoch: 0057 train_loss= 0.53544 train_acc= 0.89890 time= 0.01221
# Epoch: 0058 train_loss= 0.53515 train_acc= 0.89890 time= 0.01426
# Epoch: 0059 train_loss= 0.53482 train_acc= 0.89890 time= 0.01252
# Epoch: 0060 train_loss= 0.53447 train_acc= 0.89890 time= 0.01014
# Epoch: 0061 train_loss= 0.53406 train_acc= 0.89890 time= 0.00970
# Epoch: 0062 train_loss= 0.53357 train_acc= 0.89890 time= 0.00944
# Epoch: 0063 train_loss= 0.53296 train_acc= 0.89890 time= 0.00915
# Epoch: 0064 train_loss= 0.53154 train_acc= 0.89890 time= 0.00959
# Epoch: 0065 train_loss= 0.53403 train_acc= 0.89890 time= 0.01006
# Epoch: 0066 train_loss= 0.53397 train_acc= 0.89890 time= 0.00991
# Epoch: 0067 train_loss= 0.53143 train_acc= 0.89890 time= 0.00981
# Epoch: 0068 train_loss= 0.52801 train_acc= 0.89890 time= 0.01017
# Epoch: 0069 train_loss= 0.52112 train_acc= 0.89890 time= 0.00989
# Epoch: 0070 train_loss= 0.51663 train_acc= 0.89890 time= 0.01013
# Epoch: 0071 train_loss= 0.51475 train_acc= 0.89890 time= 0.01026
# Epoch: 0072 train_loss= 0.51292 train_acc= 0.89890 time= 0.00990
# Epoch: 0073 train_loss= 0.51097 train_acc= 0.89890 time= 0.01089
# Epoch: 0074 train_loss= 0.50978 train_acc= 0.89890 time= 0.00985
# Epoch: 0075 train_loss= 0.50980 train_acc= 0.89890 time= 0.00997
# Epoch: 0076 train_loss= 0.51138 train_acc= 0.89860 time= 0.00998
# Epoch: 0077 train_loss= 0.51315 train_acc= 0.89760 time= 0.00987
# Epoch: 0078 train_loss= 0.50724 train_acc= 0.89660 time= 0.00948
# Epoch: 0079 train_loss= 0.50681 train_acc= 0.89540 time= 0.00937
# Epoch: 0080 train_loss= 0.50641 train_acc= 0.89500 time= 0.01194
# Epoch: 0081 train_loss= 0.50604 train_acc= 0.89480 time= 0.00992
# Epoch: 0082 train_loss= 0.50568 train_acc= 0.89430 time= 0.00950
# Epoch: 0083 train_loss= 0.50533 train_acc= 0.89340 time= 0.00955
# Epoch: 0084 train_loss= 0.50498 train_acc= 0.89280 time= 0.00959
# Epoch: 0085 train_loss= 0.50465 train_acc= 0.89230 time= 0.01104
# Epoch: 0086 train_loss= 0.50435 train_acc= 0.89170 time= 0.01070
# Epoch: 0087 train_loss= 0.50406 train_acc= 0.89130 time= 0.01036
# Epoch: 0088 train_loss= 0.50376 train_acc= 0.89090 time= 0.01041
# Epoch: 0089 train_loss= 0.50346 train_acc= 0.89090 time= 0.01000
# Epoch: 0090 train_loss= 0.50318 train_acc= 0.89090 time= 0.01026
# Epoch: 0091 train_loss= 0.50289 train_acc= 0.89090 time= 0.01196
# Epoch: 0092 train_loss= 0.50261 train_acc= 0.89090 time= 0.01081
# Epoch: 0093 train_loss= 0.50233 train_acc= 0.89090 time= 0.01185
# Epoch: 0094 train_loss= 0.50204 train_acc= 0.89090 time= 0.01041
# Epoch: 0095 train_loss= 0.50174 train_acc= 0.89090 time= 0.01031
# Epoch: 0096 train_loss= 0.50143 train_acc= 0.89090 time= 0.01003
# Epoch: 0097 train_loss= 0.50109 train_acc= 0.89090 time= 0.01016
# Epoch: 0098 train_loss= 0.50072 train_acc= 0.89090 time= 0.01024
# Epoch: 0099 train_loss= 0.50034 train_acc= 0.89090 time= 0.01005
# Epoch: 0100 train_loss= 0.50000 train_acc= 0.88900 time= 0.01237
# Epoch: 0101 train_loss= 0.49976 train_acc= 0.88890 time= 0.01121
# Epoch: 0102 train_loss= 0.49942 train_acc= 0.88890 time= 0.00996
# Epoch: 0103 train_loss= 0.49907 train_acc= 0.88700 time= 0.00998
# Epoch: 0104 train_loss= 0.49876 train_acc= 0.88800 time= 0.01320
# Epoch: 0105 train_loss= 0.49846 train_acc= 0.88880 time= 0.01159
# Epoch: 0106 train_loss= 0.49818 train_acc= 0.89010 time= 0.00975
# Epoch: 0107 train_loss= 0.49794 train_acc= 0.89085 time= 0.00989
# Epoch: 0108 train_loss= 0.49773 train_acc= 0.89090 time= 0.00956
# Epoch: 0109 train_loss= 0.49753 train_acc= 0.89090 time= 0.00959
# Epoch: 0110 train_loss= 0.49733 train_acc= 0.89055 time= 0.01066
# Epoch: 0111 train_loss= 0.49691 train_acc= 0.88900 time= 0.00971
# Epoch: 0112 train_loss= 0.50245 train_acc= 0.88880 time= 0.00979
# Epoch: 0113 train_loss= 0.49695 train_acc= 0.89060 time= 0.01077
# Epoch: 0114 train_loss= 0.49673 train_acc= 0.89080 time= 0.01062
# Epoch: 0115 train_loss= 0.49651 train_acc= 0.89090 time= 0.01100
# Epoch: 0116 train_loss= 0.49630 train_acc= 0.89080 time= 0.01118
# Epoch: 0117 train_loss= 0.49607 train_acc= 0.89080 time= 0.01053
# Epoch: 0118 train_loss= 0.49586 train_acc= 0.89060 time= 0.01037
# Epoch: 0119 train_loss= 0.49568 train_acc= 0.89005 time= 0.01166
# Epoch: 0120 train_loss= 0.49520 train_acc= 0.88985 time= 0.01367
# Epoch: 0121 train_loss= 0.49539 train_acc= 0.89060 time= 0.01075
# Epoch: 0122 train_loss= 0.49525 train_acc= 0.89075 time= 0.01193
# Epoch: 0123 train_loss= 0.49509 train_acc= 0.89085 time= 0.01083
# Epoch: 0124 train_loss= 0.49499 train_acc= 0.89080 time= 0.01028
# Epoch: 0125 train_loss= 0.49490 train_acc= 0.89080 time= 0.01048
# Epoch: 0126 train_loss= 0.49478 train_acc= 0.89085 time= 0.01074
# Epoch: 0127 train_loss= 0.49433 train_acc= 0.89085 time= 0.01236
# Epoch: 0128 train_loss= 0.49422 train_acc= 0.89080 time= 0.01670
# Epoch: 0129 train_loss= 0.49410 train_acc= 0.89080 time= 0.01715
# Epoch: 0130 train_loss= 0.49400 train_acc= 0.89090 time= 0.01319
# Epoch: 0131 train_loss= 0.49427 train_acc= 0.89090 time= 0.01062
# Epoch: 0132 train_loss= 0.49418 train_acc= 0.89090 time= 0.01102
# Epoch: 0133 train_loss= 0.49409 train_acc= 0.89090 time= 0.01082
# Epoch: 0134 train_loss= 0.49402 train_acc= 0.89090 time= 0.01036
# Epoch: 0135 train_loss= 0.49397 train_acc= 0.89090 time= 0.01122
# Epoch: 0136 train_loss= 0.49389 train_acc= 0.89090 time= 0.01437
# Epoch: 0137 train_loss= 0.49385 train_acc= 0.89090 time= 0.01140
# Epoch: 0138 train_loss= 0.49378 train_acc= 0.89090 time= 0.01055
# Epoch: 0139 train_loss= 0.49371 train_acc= 0.89090 time= 0.01064
# Epoch: 0140 train_loss= 0.49366 train_acc= 0.89090 time= 0.01049
# Epoch: 0141 train_loss= 0.49360 train_acc= 0.89090 time= 0.01037
# Epoch: 0142 train_loss= 0.49356 train_acc= 0.89090 time= 0.01051
# Epoch: 0143 train_loss= 0.49350 train_acc= 0.89090 time= 0.01041
# Epoch: 0144 train_loss= 0.49346 train_acc= 0.89090 time= 0.01020
# Epoch: 0145 train_loss= 0.49342 train_acc= 0.89090 time= 0.01042
# Epoch: 0146 train_loss= 0.49337 train_acc= 0.89090 time= 0.01063
# Epoch: 0147 train_loss= 0.49333 train_acc= 0.89090 time= 0.01060
# Epoch: 0148 train_loss= 0.49329 train_acc= 0.89090 time= 0.01019
# Epoch: 0149 train_loss= 0.49325 train_acc= 0.89090 time= 0.01150
# Epoch: 0150 train_loss= 0.49322 train_acc= 0.89090 time= 0.01071
# Epoch: 0151 train_loss= 0.49319 train_acc= 0.89090 time= 0.01103
# Epoch: 0152 train_loss= 0.49315 train_acc= 0.89090 time= 0.01005
# Epoch: 0153 train_loss= 0.49312 train_acc= 0.89090 time= 0.01003
# Epoch: 0154 train_loss= 0.49308 train_acc= 0.89090 time= 0.01023
# Epoch: 0155 train_loss= 0.49306 train_acc= 0.89090 time= 0.01133
# Epoch: 0156 train_loss= 0.49303 train_acc= 0.89090 time= 0.01229
# Epoch: 0157 train_loss= 0.49300 train_acc= 0.89090 time= 0.01058
# Epoch: 0158 train_loss= 0.49297 train_acc= 0.89090 time= 0.01034
# Epoch: 0159 train_loss= 0.49295 train_acc= 0.89090 time= 0.01036
# Epoch: 0160 train_loss= 0.49292 train_acc= 0.89090 time= 0.01045
# Epoch: 0161 train_loss= 0.49288 train_acc= 0.89090 time= 0.01014
# Epoch: 0162 train_loss= 0.49285 train_acc= 0.89090 time= 0.01030
# Epoch: 0163 train_loss= 0.49283 train_acc= 0.89090 time= 0.01066
# Epoch: 0164 train_loss= 0.49281 train_acc= 0.89090 time= 0.01021
# Epoch: 0165 train_loss= 0.49279 train_acc= 0.89090 time= 0.01124
# Epoch: 0166 train_loss= 0.49278 train_acc= 0.89090 time= 0.01065
# Epoch: 0167 train_loss= 0.49276 train_acc= 0.89090 time= 0.01127
# Epoch: 0168 train_loss= 0.49274 train_acc= 0.89090 time= 0.01044
# Epoch: 0169 train_loss= 0.49272 train_acc= 0.89090 time= 0.01069
# Epoch: 0170 train_loss= 0.49271 train_acc= 0.89080 time= 0.01006
# Epoch: 0171 train_loss= 0.49270 train_acc= 0.89090 time= 0.01113
# Epoch: 0172 train_loss= 0.49270 train_acc= 0.89090 time= 0.01374
# Epoch: 0173 train_loss= 0.49266 train_acc= 0.89090 time= 0.01367
# Epoch: 0174 train_loss= 0.49266 train_acc= 0.89090 time= 0.01435
# Epoch: 0175 train_loss= 0.49805 train_acc= 0.89090 time= 0.01280
# Epoch: 0176 train_loss= 0.49284 train_acc= 0.89090 time= 0.01102
# Epoch: 0177 train_loss= 0.49283 train_acc= 0.89090 time= 0.01102
# Epoch: 0178 train_loss= 0.49272 train_acc= 0.89090 time= 0.01111
# Epoch: 0179 train_loss= 0.49287 train_acc= 0.89090 time= 0.01126
# Epoch: 0180 train_loss= 0.49273 train_acc= 0.89090 time= 0.01165
# Epoch: 0181 train_loss= 0.49272 train_acc= 0.89090 time= 0.01270
# Epoch: 0182 train_loss= 0.49278 train_acc= 0.89090 time= 0.01107
# Epoch: 0183 train_loss= 0.49269 train_acc= 0.89090 time= 0.01092
# Epoch: 0184 train_loss= 0.49264 train_acc= 0.89090 time= 0.01106
# Epoch: 0185 train_loss= 0.49268 train_acc= 0.89090 time= 0.01109
# Epoch: 0186 train_loss= 0.49261 train_acc= 0.89090 time= 0.01074
# Epoch: 0187 train_loss= 0.49255 train_acc= 0.89090 time= 0.01025
# Epoch: 0188 train_loss= 0.49256 train_acc= 0.89090 time= 0.01044
# Epoch: 0189 train_loss= 0.49254 train_acc= 0.89090 time= 0.01021
# Epoch: 0190 train_loss= 0.49248 train_acc= 0.89090 time= 0.01045
# Epoch: 0191 train_loss= 0.49250 train_acc= 0.89090 time= 0.01044
# Epoch: 0192 train_loss= 0.49250 train_acc= 0.89090 time= 0.01050
# Epoch: 0193 train_loss= 0.49246 train_acc= 0.89090 time= 0.01690
# Epoch: 0194 train_loss= 0.49245 train_acc= 0.89090 time= 0.01138
# Epoch: 0195 train_loss= 0.49244 train_acc= 0.89090 time= 0.01065
# Epoch: 0196 train_loss= 0.49242 train_acc= 0.89090 time= 0.01047
# Epoch: 0197 train_loss= 0.49241 train_acc= 0.89090 time= 0.01067
# Epoch: 0198 train_loss= 0.49241 train_acc= 0.89090 time= 0.01065
# Epoch: 0199 train_loss= 0.49238 train_acc= 0.89090 time= 0.01049
# Epoch: 0200 train_loss= 0.49238 train_acc= 0.89090 time= 0.01052
# Epoch: 0201 train_loss= 0.49238 train_acc= 0.89090 time= 0.01102
# Epoch: 0202 train_loss= 0.49235 train_acc= 0.89090 time= 0.01215
# Epoch: 0203 train_loss= 0.49235 train_acc= 0.89090 time= 0.01058
# Epoch: 0204 train_loss= 0.49234 train_acc= 0.89090 time= 0.01037
# Epoch: 0205 train_loss= 0.49232 train_acc= 0.89090 time= 0.01059
# Epoch: 0206 train_loss= 0.49232 train_acc= 0.89090 time= 0.01040
# Epoch: 0207 train_loss= 0.49231 train_acc= 0.89090 time= 0.01040
# Epoch: 0208 train_loss= 0.49229 train_acc= 0.89090 time= 0.01044
# Epoch: 0209 train_loss= 0.49229 train_acc= 0.89090 time= 0.01056
# Epoch: 0210 train_loss= 0.49228 train_acc= 0.89090 time= 0.01254
# Epoch: 0211 train_loss= 0.49227 train_acc= 0.89090 time= 0.01240
# Epoch: 0212 train_loss= 0.49227 train_acc= 0.89090 time= 0.01439
# Epoch: 0213 train_loss= 0.49226 train_acc= 0.89090 time= 0.01021
# Epoch: 0214 train_loss= 0.49225 train_acc= 0.89090 time= 0.01036
# Epoch: 0215 train_loss= 0.49225 train_acc= 0.89090 time= 0.00987
# Epoch: 0216 train_loss= 0.49224 train_acc= 0.89090 time= 0.00948
# Epoch: 0217 train_loss= 0.49223 train_acc= 0.89090 time= 0.00940
# Epoch: 0218 train_loss= 0.49223 train_acc= 0.89090 time= 0.00923
# Epoch: 0219 train_loss= 0.49222 train_acc= 0.89090 time= 0.01029
# Epoch: 0220 train_loss= 0.49221 train_acc= 0.89090 time= 0.01056
# Epoch: 0221 train_loss= 0.49221 train_acc= 0.89090 time= 0.01493
# Epoch: 0222 train_loss= 0.49220 train_acc= 0.89090 time= 0.01531
# Epoch: 0223 train_loss= 0.49220 train_acc= 0.89090 time= 0.01177
# Epoch: 0224 train_loss= 0.49219 train_acc= 0.89090 time= 0.00939
# Epoch: 0225 train_loss= 0.49218 train_acc= 0.89090 time= 0.00961
# Epoch: 0226 train_loss= 0.49218 train_acc= 0.89090 time= 0.00939
# Epoch: 0227 train_loss= 0.49218 train_acc= 0.89090 time= 0.00921
# Epoch: 0228 train_loss= 0.49217 train_acc= 0.89090 time= 0.01160
# Epoch: 0229 train_loss= 0.49217 train_acc= 0.89090 time= 0.01182
# Epoch: 0230 train_loss= 0.49216 train_acc= 0.89090 time= 0.01513
# Epoch: 0231 train_loss= 0.49216 train_acc= 0.89090 time= 0.01163
# Epoch: 0232 train_loss= 0.49215 train_acc= 0.89090 time= 0.00966
# Epoch: 0233 train_loss= 0.49215 train_acc= 0.89090 time= 0.00935
# Epoch: 0234 train_loss= 0.49214 train_acc= 0.89090 time= 0.00907
# Epoch: 0235 train_loss= 0.49214 train_acc= 0.89090 time= 0.01021
# Epoch: 0236 train_loss= 0.49213 train_acc= 0.89090 time= 0.00974
# Epoch: 0237 train_loss= 0.49213 train_acc= 0.89090 time= 0.00932
# Epoch: 0238 train_loss= 0.49213 train_acc= 0.89090 time= 0.00978
# Epoch: 0239 train_loss= 0.49212 train_acc= 0.89090 time= 0.01169
# Epoch: 0240 train_loss= 0.49212 train_acc= 0.89090 time= 0.01089
# Epoch: 0241 train_loss= 0.49211 train_acc= 0.89090 time= 0.01027
# Epoch: 0242 train_loss= 0.49211 train_acc= 0.89090 time= 0.00913
# Epoch: 0243 train_loss= 0.49211 train_acc= 0.89090 time= 0.01015
# Epoch: 0244 train_loss= 0.49210 train_acc= 0.89090 time= 0.00930
# Epoch: 0245 train_loss= 0.49210 train_acc= 0.89090 time= 0.00946
# Epoch: 0246 train_loss= 0.49210 train_acc= 0.89090 time= 0.00921
# Epoch: 0247 train_loss= 0.49209 train_acc= 0.89090 time= 0.00928
# Epoch: 0248 train_loss= 0.49209 train_acc= 0.89090 time= 0.00969
# Epoch: 0249 train_loss= 0.49209 train_acc= 0.89090 time= 0.00938
# Epoch: 0250 train_loss= 0.49208 train_acc= 0.89090 time= 0.00910
# Epoch: 0251 train_loss= 0.49208 train_acc= 0.89090 time= 0.00914
# Epoch: 0252 train_loss= 0.49208 train_acc= 0.89090 time= 0.01179
# Epoch: 0253 train_loss= 0.49207 train_acc= 0.89090 time= 0.01074
# Epoch: 0254 train_loss= 0.49207 train_acc= 0.89090 time= 0.01009
# Epoch: 0255 train_loss= 0.49207 train_acc= 0.89090 time= 0.01024
# Epoch: 0256 train_loss= 0.49206 train_acc= 0.89090 time= 0.00978
# Epoch: 0257 train_loss= 0.49206 train_acc= 0.89090 time= 0.00994
# Epoch: 0258 train_loss= 0.49205 train_acc= 0.89090 time= 0.00963
# Epoch: 0259 train_loss= 0.49180 train_acc= 0.89090 time= 0.01193
# Epoch: 0260 train_loss= 0.49180 train_acc= 0.89090 time= 0.01082
# Epoch: 0261 train_loss= 0.49179 train_acc= 0.89090 time= 0.01005
# Epoch: 0262 train_loss= 0.49179 train_acc= 0.89090 time= 0.01003
# Epoch: 0263 train_loss= 0.49179 train_acc= 0.89090 time= 0.00979
# Epoch: 0264 train_loss= 0.49179 train_acc= 0.89090 time= 0.00994
# Epoch: 0265 train_loss= 0.49178 train_acc= 0.89090 time= 0.01139
# Epoch: 0266 train_loss= 0.49178 train_acc= 0.89090 time= 0.00999
# Epoch: 0267 train_loss= 0.49136 train_acc= 0.89090 time= 0.01256
# Epoch: 0268 train_loss= 0.49137 train_acc= 0.89090 time= 0.01143
# Epoch: 0269 train_loss= 0.49137 train_acc= 0.89090 time= 0.01079
# Epoch: 0270 train_loss= 0.49282 train_acc= 0.89090 time= 0.01003
# Epoch: 0271 train_loss= 0.49138 train_acc= 0.89090 time= 0.01168
# Epoch: 0272 train_loss= 0.49137 train_acc= 0.89090 time= 0.01256
# Epoch: 0273 train_loss= 0.49179 train_acc= 0.89090 time= 0.01008
# Epoch: 0274 train_loss= 0.49135 train_acc= 0.89090 time= 0.01187
# Epoch: 0275 train_loss= 0.49134 train_acc= 0.89090 time= 0.00971
# Epoch: 0276 train_loss= 0.49137 train_acc= 0.89090 time= 0.00954
# Epoch: 0277 train_loss= 0.49180 train_acc= 0.89090 time= 0.00978
# Epoch: 0278 train_loss= 0.49204 train_acc= 0.89090 time= 0.00958
# Epoch: 0279 train_loss= 0.49202 train_acc= 0.89090 time= 0.00914
# Epoch: 0280 train_loss= 0.49210 train_acc= 0.89090 time= 0.00972
# Epoch: 0281 train_loss= 0.49215 train_acc= 0.89090 time= 0.00965
# Epoch: 0282 train_loss= 0.49204 train_acc= 0.89090 time= 0.00971
# Epoch: 0283 train_loss= 0.49207 train_acc= 0.89090 time= 0.00969
# Epoch: 0284 train_loss= 0.49210 train_acc= 0.89090 time= 0.01030
# Epoch: 0285 train_loss= 0.49204 train_acc= 0.89090 time= 0.01007
# Epoch: 0286 train_loss= 0.49209 train_acc= 0.89090 time= 0.01072
# Epoch: 0287 train_loss= 0.49204 train_acc= 0.89090 time= 0.01124
# Epoch: 0288 train_loss= 0.49205 train_acc= 0.89090 time= 0.01198
# Epoch: 0289 train_loss= 0.49204 train_acc= 0.89090 time= 0.01099
# Epoch: 0290 train_loss= 0.49202 train_acc= 0.89090 time= 0.00940
# Epoch: 0291 train_loss= 0.49202 train_acc= 0.89090 time= 0.01227
# Epoch: 0292 train_loss= 0.49201 train_acc= 0.89090 time= 0.01031
# Epoch: 0293 train_loss= 0.49201 train_acc= 0.89090 time= 0.00964
# Epoch: 0294 train_loss= 0.49201 train_acc= 0.89090 time= 0.00979
# Epoch: 0295 train_loss= 0.49200 train_acc= 0.89090 time= 0.00922
# Epoch: 0296 train_loss= 0.49201 train_acc= 0.89090 time= 0.00954
# Epoch: 0297 train_loss= 0.49199 train_acc= 0.89090 time= 0.00929
# Epoch: 0298 train_loss= 0.49200 train_acc= 0.89090 time= 0.01052
# Epoch: 0299 train_loss= 0.49199 train_acc= 0.89090 time= 0.01014
# Epoch: 0300 train_loss= 0.49199 train_acc= 0.89090 time= 0.00938
# Epoch: 0301 train_loss= 0.49199 train_acc= 0.89090 time= 0.00961
# Epoch: 0302 train_loss= 0.49198 train_acc= 0.89090 time= 0.00951
# Epoch: 0303 train_loss= 0.49198 train_acc= 0.89090 time= 0.00958
# Epoch: 0304 train_loss= 0.49197 train_acc= 0.89090 time= 0.00962
# Epoch: 0305 train_loss= 0.49198 train_acc= 0.89090 time= 0.01081
# Epoch: 0306 train_loss= 0.49197 train_acc= 0.89090 time= 0.01170
# Epoch: 0307 train_loss= 0.49197 train_acc= 0.89090 time= 0.01007
# Epoch: 0308 train_loss= 0.49197 train_acc= 0.89090 time= 0.00939
# Epoch: 0309 train_loss= 0.49197 train_acc= 0.89090 time= 0.01002
# Epoch: 0310 train_loss= 0.49197 train_acc= 0.89090 time= 0.00985
# Epoch: 0311 train_loss= 0.49197 train_acc= 0.89090 time= 0.00967
# Epoch: 0312 train_loss= 0.49196 train_acc= 0.89090 time= 0.01191
# Epoch: 0313 train_loss= 0.49196 train_acc= 0.89090 time= 0.00984
# Epoch: 0314 train_loss= 0.49196 train_acc= 0.89090 time= 0.00958
# Epoch: 0315 train_loss= 0.49196 train_acc= 0.89090 time= 0.00939
# Epoch: 0316 train_loss= 0.49196 train_acc= 0.89090 time= 0.00920
# Epoch: 0317 train_loss= 0.49196 train_acc= 0.89090 time= 0.00929
# Epoch: 0318 train_loss= 0.49196 train_acc= 0.89090 time= 0.01226
# Epoch: 0319 train_loss= 0.49195 train_acc= 0.89090 time= 0.01524
# Epoch: 0320 train_loss= 0.49196 train_acc= 0.89090 time= 0.04406
# Epoch: 0321 train_loss= 0.49195 train_acc= 0.89090 time= 0.02934
# Epoch: 0322 train_loss= 0.49195 train_acc= 0.89090 time= 0.01544
# Epoch: 0323 train_loss= 0.49195 train_acc= 0.89090 time= 0.01461
# Epoch: 0324 train_loss= 0.49195 train_acc= 0.89090 time= 0.01512
# Epoch: 0325 train_loss= 0.49195 train_acc= 0.89090 time= 0.01573
# Epoch: 0326 train_loss= 0.49195 train_acc= 0.89090 time= 0.01582
# Epoch: 0327 train_loss= 0.49195 train_acc= 0.89090 time= 0.01471
# Epoch: 0328 train_loss= 0.49194 train_acc= 0.89090 time= 0.01575
# Epoch: 0329 train_loss= 0.49194 train_acc= 0.89090 time= 0.01482
# Epoch: 0330 train_loss= 0.49194 train_acc= 0.89090 time= 0.01517
# Epoch: 0331 train_loss= 0.49194 train_acc= 0.89090 time= 0.01456
# Epoch: 0332 train_loss= 0.49194 train_acc= 0.89090 time= 0.01511
# Epoch: 0333 train_loss= 0.49194 train_acc= 0.89090 time= 0.01450
# Epoch: 0334 train_loss= 0.49194 train_acc= 0.89090 time= 0.01575
# Epoch: 0335 train_loss= 0.49194 train_acc= 0.89090 time= 0.01555
# Epoch: 0336 train_loss= 0.49194 train_acc= 0.89090 time= 0.01990
# Epoch: 0337 train_loss= 0.49194 train_acc= 0.89090 time= 0.02963
# Epoch: 0338 train_loss= 0.49194 train_acc= 0.89090 time= 0.01609
# Epoch: 0339 train_loss= 0.49194 train_acc= 0.89090 time= 0.01509
# Epoch: 0340 train_loss= 0.49194 train_acc= 0.89090 time= 0.01530
# Epoch: 0341 train_loss= 0.49194 train_acc= 0.89090 time= 0.01504
# Epoch: 0342 train_loss= 0.49194 train_acc= 0.89090 time= 0.01514
# Epoch: 0343 train_loss= 0.49193 train_acc= 0.89090 time= 0.01521
# Epoch: 0344 train_loss= 0.49193 train_acc= 0.89090 time= 0.01498
# Epoch: 0345 train_loss= 0.49194 train_acc= 0.89090 time= 0.01537
# Epoch: 0346 train_loss= 0.49196 train_acc= 0.89090 time= 0.01499
# Epoch: 0347 train_loss= 0.49199 train_acc= 0.89090 time= 0.01539
# Epoch: 0348 train_loss= 0.49195 train_acc= 0.89090 time= 0.01569
# Epoch: 0349 train_loss= 0.49196 train_acc= 0.89090 time= 0.01204
# Epoch: 0350 train_loss= 0.49195 train_acc= 0.89090 time= 0.00944
# Epoch: 0351 train_loss= 0.49195 train_acc= 0.89090 time= 0.01093
# Epoch: 0352 train_loss= 0.49195 train_acc= 0.89090 time= 0.01218
# Epoch: 0353 train_loss= 0.49194 train_acc= 0.89090 time= 0.00966
# Epoch: 0354 train_loss= 0.49195 train_acc= 0.89090 time= 0.00931
# Epoch: 0355 train_loss= 0.49193 train_acc= 0.89100 time= 0.01111
# Epoch: 0356 train_loss= 0.49195 train_acc= 0.89100 time= 0.00942
# Epoch: 0357 train_loss= 0.49193 train_acc= 0.89100 time= 0.00908
# Epoch: 0358 train_loss= 0.49194 train_acc= 0.89100 time= 0.00951
# Epoch: 0359 train_loss= 0.49194 train_acc= 0.89100 time= 0.00906
# Epoch: 0360 train_loss= 0.49193 train_acc= 0.89110 time= 0.00901
# Epoch: 0361 train_loss= 0.49193 train_acc= 0.89110 time= 0.00894
# Epoch: 0362 train_loss= 0.49193 train_acc= 0.89110 time= 0.00960
# Epoch: 0363 train_loss= 0.49193 train_acc= 0.89110 time= 0.00899
# Epoch: 0364 train_loss= 0.49193 train_acc= 0.89110 time= 0.00911
# Epoch: 0365 train_loss= 0.49193 train_acc= 0.89110 time= 0.00909
# Epoch: 0366 train_loss= 0.49192 train_acc= 0.89110 time= 0.00928
# Epoch: 0367 train_loss= 0.49193 train_acc= 0.89110 time= 0.00920
# Epoch: 0368 train_loss= 0.49192 train_acc= 0.89110 time= 0.00974
# Epoch: 0369 train_loss= 0.49192 train_acc= 0.89110 time= 0.00930
# Epoch: 0370 train_loss= 0.49192 train_acc= 0.89110 time= 0.00926
# Epoch: 0371 train_loss= 0.49192 train_acc= 0.89110 time= 0.00898
# Epoch: 0372 train_loss= 0.49192 train_acc= 0.89110 time= 0.00972
# Epoch: 0373 train_loss= 0.49192 train_acc= 0.89110 time= 0.00930
# Epoch: 0374 train_loss= 0.49191 train_acc= 0.89110 time= 0.01258
# Epoch: 0375 train_loss= 0.49191 train_acc= 0.89110 time= 0.00958
# Epoch: 0376 train_loss= 0.49191 train_acc= 0.89110 time= 0.00950
# Epoch: 0377 train_loss= 0.49191 train_acc= 0.89110 time= 0.00943
# Epoch: 0378 train_loss= 0.49191 train_acc= 0.89110 time= 0.00910
# Epoch: 0379 train_loss= 0.49191 train_acc= 0.89110 time= 0.00898
# Epoch: 0380 train_loss= 0.49191 train_acc= 0.89110 time= 0.01105
# Epoch: 0381 train_loss= 0.49191 train_acc= 0.89110 time= 0.01012
# Epoch: 0382 train_loss= 0.49192 train_acc= 0.89110 time= 0.00938
# Epoch: 0383 train_loss= 0.49192 train_acc= 0.89110 time= 0.01230
# Epoch: 0384 train_loss= 0.49191 train_acc= 0.89110 time= 0.01638
# Epoch: 0385 train_loss= 0.49192 train_acc= 0.89110 time= 0.01520
# Epoch: 0386 train_loss= 0.49192 train_acc= 0.89110 time= 0.01492
# Epoch: 0387 train_loss= 0.49192 train_acc= 0.89110 time= 0.01500
# Epoch: 0388 train_loss= 0.49192 train_acc= 0.89120 time= 0.01550
# Epoch: 0389 train_loss= 0.49192 train_acc= 0.89120 time= 0.01712
# Epoch: 0390 train_loss= 0.49191 train_acc= 0.89120 time= 0.04138
# Epoch: 0391 train_loss= 0.49191 train_acc= 0.89120 time= 0.03484
# Epoch: 0392 train_loss= 0.49191 train_acc= 0.89130 time= 0.04157
# Epoch: 0393 train_loss= 0.49191 train_acc= 0.89130 time= 0.04438
# Epoch: 0394 train_loss= 0.49191 train_acc= 0.89150 time= 0.07494
# Epoch: 0395 train_loss= 0.49191 train_acc= 0.89150 time= 0.03978
# Epoch: 0396 train_loss= 0.49191 train_acc= 0.89160 time= 0.04050
# Epoch: 0397 train_loss= 0.49190 train_acc= 0.89160 time= 0.01580
# Epoch: 0398 train_loss= 0.49190 train_acc= 0.89160 time= 0.01649
# Epoch: 0399 train_loss= 0.49190 train_acc= 0.89160 time= 0.01587
# Epoch: 0400 train_loss= 0.49191 train_acc= 0.89160 time= 0.01672
# Epoch: 0401 train_loss= 0.49190 train_acc= 0.89160 time= 0.01654
# Epoch: 0402 train_loss= 0.49191 train_acc= 0.89160 time= 0.01623
# Epoch: 0403 train_loss= 0.49191 train_acc= 0.89180 time= 0.01754
# Epoch: 0404 train_loss= 0.49191 train_acc= 0.89190 time= 0.01676
# Epoch: 0405 train_loss= 0.49191 train_acc= 0.89190 time= 0.03238
# Epoch: 0406 train_loss= 0.49191 train_acc= 0.89200 time= 0.04242
# Epoch: 0407 train_loss= 0.49191 train_acc= 0.89200 time= 0.02242
# Epoch: 0408 train_loss= 0.49190 train_acc= 0.89230 time= 0.02137
# Epoch: 0409 train_loss= 0.49191 train_acc= 0.89230 time= 0.01665
# Epoch: 0410 train_loss= 0.49190 train_acc= 0.89240 time= 0.01921
# Epoch: 0411 train_loss= 0.49190 train_acc= 0.89240 time= 0.01684
# Epoch: 0412 train_loss= 0.49190 train_acc= 0.89240 time= 0.01655
# Epoch: 0413 train_loss= 0.49190 train_acc= 0.89250 time= 0.01610
# Epoch: 0414 train_loss= 0.49190 train_acc= 0.89250 time= 0.01678
# Epoch: 0415 train_loss= 0.49190 train_acc= 0.89250 time= 0.01788
# Epoch: 0416 train_loss= 0.49190 train_acc= 0.89250 time= 0.01742
# Epoch: 0417 train_loss= 0.49190 train_acc= 0.89250 time= 0.03179
# Epoch: 0418 train_loss= 0.49190 train_acc= 0.89250 time= 0.02843
# Epoch: 0419 train_loss= 0.49190 train_acc= 0.89250 time= 0.02223
# Epoch: 0420 train_loss= 0.49190 train_acc= 0.89260 time= 0.04363
# Epoch: 0421 train_loss= 0.49189 train_acc= 0.89260 time= 0.01637
# Epoch: 0422 train_loss= 0.49189 train_acc= 0.89260 time= 0.01746
# Epoch: 0423 train_loss= 0.49189 train_acc= 0.89260 time= 0.03119
# Epoch: 0424 train_loss= 0.49189 train_acc= 0.89270 time= 0.03758
# Epoch: 0425 train_loss= 0.49189 train_acc= 0.89290 time= 0.02935
# Epoch: 0426 train_loss= 0.49189 train_acc= 0.89290 time= 0.01674
# Epoch: 0427 train_loss= 0.49189 train_acc= 0.89310 time= 0.01555
# Epoch: 0428 train_loss= 0.49190 train_acc= 0.89330 time= 0.01714
# Epoch: 0429 train_loss= 0.49190 train_acc= 0.89340 time= 0.02962
# Epoch: 0430 train_loss= 0.49190 train_acc= 0.89330 time= 0.02260
# Epoch: 0431 train_loss= 0.49190 train_acc= 0.89350 time= 0.02229
# Epoch: 0432 train_loss= 0.49189 train_acc= 0.89360 time= 0.06571
# Epoch: 0433 train_loss= 0.49189 train_acc= 0.89350 time= 0.06686
# Epoch: 0434 train_loss= 0.49189 train_acc= 0.89350 time= 0.05146
# Epoch: 0435 train_loss= 0.49189 train_acc= 0.89360 time= 0.02329
# Epoch: 0436 train_loss= 0.49189 train_acc= 0.89360 time= 0.03963
# Epoch: 0437 train_loss= 0.49189 train_acc= 0.89360 time= 0.02941
# Epoch: 0438 train_loss= 0.49189 train_acc= 0.89370 time= 0.07310
# Epoch: 0439 train_loss= 0.49189 train_acc= 0.89370 time= 0.01972
# Epoch: 0440 train_loss= 0.49189 train_acc= 0.89370 time= 0.01698
# Epoch: 0441 train_loss= 0.49189 train_acc= 0.89370 time= 0.03194
# Epoch: 0442 train_loss= 0.49189 train_acc= 0.89380 time= 0.01772
# Epoch: 0443 train_loss= 0.49189 train_acc= 0.89390 time= 0.01490
# Epoch: 0444 train_loss= 0.49190 train_acc= 0.89390 time= 0.05102
# Epoch: 0445 train_loss= 0.49190 train_acc= 0.89410 time= 0.03857
# Epoch: 0446 train_loss= 0.49189 train_acc= 0.89420 time= 0.03152
# Epoch: 0447 train_loss= 0.49189 train_acc= 0.89430 time= 0.02754
# Epoch: 0448 train_loss= 0.49190 train_acc= 0.89440 time= 0.02523
# Epoch: 0449 train_loss= 0.49190 train_acc= 0.89450 time= 0.03920
# Epoch: 0450 train_loss= 0.49189 train_acc= 0.89450 time= 0.01860
# Epoch: 0451 train_loss= 0.49189 train_acc= 0.89480 time= 0.03093
# Epoch: 0452 train_loss= 0.49191 train_acc= 0.89490 time= 0.03943
# Epoch: 0453 train_loss= 0.49190 train_acc= 0.89490 time= 0.02360
# Epoch: 0454 train_loss= 0.49190 train_acc= 0.89480 time= 0.05218
# Epoch: 0455 train_loss= 0.49191 train_acc= 0.89490 time= 0.02760
# Epoch: 0456 train_loss= 0.49192 train_acc= 0.89480 time= 0.02643
# Epoch: 0457 train_loss= 0.49190 train_acc= 0.89490 time= 0.01936
# Epoch: 0458 train_loss= 0.49191 train_acc= 0.89490 time= 0.02841
# Epoch: 0459 train_loss= 0.49190 train_acc= 0.89490 time= 0.03984
# Epoch: 0460 train_loss= 0.49191 train_acc= 0.89500 time= 0.02059
# Epoch: 0461 train_loss= 0.49191 train_acc= 0.89500 time= 0.02155
# Epoch: 0462 train_loss= 0.49189 train_acc= 0.89500 time= 0.02409
# Epoch: 0463 train_loss= 0.49190 train_acc= 0.89500 time= 0.02057
# Epoch: 0464 train_loss= 0.49190 train_acc= 0.89500 time= 0.01624
# Epoch: 0465 train_loss= 0.49189 train_acc= 0.89500 time= 0.02519
# Epoch: 0466 train_loss= 0.49189 train_acc= 0.89500 time= 0.01644
# Epoch: 0467 train_loss= 0.49189 train_acc= 0.89510 time= 0.01695
# Epoch: 0468 train_loss= 0.49189 train_acc= 0.89510 time= 0.06792
# Epoch: 0469 train_loss= 0.49189 train_acc= 0.89510 time= 0.04119
# Epoch: 0470 train_loss= 0.49189 train_acc= 0.89520 time= 0.05074
# Epoch: 0471 train_loss= 0.49189 train_acc= 0.89520 time= 0.06085
# Epoch: 0472 train_loss= 0.49189 train_acc= 0.89520 time= 0.06979
# Epoch: 0473 train_loss= 0.49188 train_acc= 0.89530 time= 0.03885
# Epoch: 0474 train_loss= 0.49189 train_acc= 0.89530 time= 0.04092
# Epoch: 0475 train_loss= 0.49188 train_acc= 0.89530 time= 0.01710
# Epoch: 0476 train_loss= 0.49188 train_acc= 0.89530 time= 0.02963
# Epoch: 0477 train_loss= 0.49188 train_acc= 0.89550 time= 0.04137
# Epoch: 0478 train_loss= 0.49188 train_acc= 0.89560 time= 0.02434
# Epoch: 0479 train_loss= 0.49188 train_acc= 0.89560 time= 0.03296
# Epoch: 0480 train_loss= 0.49188 train_acc= 0.89560 time= 0.04735
# Epoch: 0481 train_loss= 0.49188 train_acc= 0.89560 time= 0.09019
# Epoch: 0482 train_loss= 0.49188 train_acc= 0.89580 time= 0.06913
# Epoch: 0483 train_loss= 0.49191 train_acc= 0.89580 time= 0.06167
# Epoch: 0484 train_loss= 0.49191 train_acc= 0.89580 time= 0.06870
# Epoch: 0485 train_loss= 0.49189 train_acc= 0.89580 time= 0.07102
# Epoch: 0486 train_loss= 0.49191 train_acc= 0.89580 time= 0.10888
# Epoch: 0487 train_loss= 0.49190 train_acc= 0.89580 time= 0.05686
# Epoch: 0488 train_loss= 0.49190 train_acc= 0.89590 time= 0.07454
# Epoch: 0489 train_loss= 0.49190 train_acc= 0.89590 time= 0.08505
# Epoch: 0490 train_loss= 0.49189 train_acc= 0.89590 time= 0.10032
# Epoch: 0491 train_loss= 0.49190 train_acc= 0.89590 time= 0.10920
# Epoch: 0492 train_loss= 0.49188 train_acc= 0.89590 time= 0.08068
# Epoch: 0493 train_loss= 0.49189 train_acc= 0.89590 time= 0.07645
# Epoch: 0494 train_loss= 0.49188 train_acc= 0.89590 time= 0.07583
# Epoch: 0495 train_loss= 0.49188 train_acc= 0.89600 time= 0.04486
# Epoch: 0496 train_loss= 0.49189 train_acc= 0.89610 time= 0.06012
# Epoch: 0497 train_loss= 0.49188 train_acc= 0.89610 time= 0.07322
# Epoch: 0498 train_loss= 0.49188 train_acc= 0.89630 time= 0.04472
# Epoch: 0499 train_loss= 0.49188 train_acc= 0.89630 time= 0.06081
# Epoch: 0500 train_loss= 0.49188 train_acc= 0.89630 time= 0.06646
# Purity 1.0
# Purity 0.98

# %%
model.eval()

# Recompute adj_label, positive_weight, normalization_factor (norm), and weight_tensor
adj_label_tuple = convert_sparse_matrix(adjacency_sparse)
adj_label = torch.sparse.FloatTensor(
    torch.LongTensor(adj_label_tuple[0].T),
    torch.FloatTensor(adj_label_tuple[1]),
    torch.Size(adj_label_tuple[2])
)

positive_weight = float(
    adjacency_sparse.shape[0] * adjacency_sparse.shape[0] - adjacency_sparse.sum()
) / adjacency_sparse.sum()

norm = (
    adjacency_sparse.shape[0] * adjacency_sparse.shape[0] /
    float((adjacency_sparse.shape[0] * adjacency_sparse.shape[0] - adjacency_sparse.sum()) * 2)
)

label_mask = adj_label.to_dense().view(-1) == 1
weight_tensor = torch.ones(label_mask.size(0))
weight_tensor[label_mask] = positive_weight

# Pass all required arguments to the model's forward method
_, _, latent_embeddings, soft_assignments = model(
    node_features,
    500, # Using 500 for epoch as it was in the original call
    adj_label,
    weight_tensor,
    norm
)

encoded = latent_embeddings.cpu().detach().numpy()
centroids = model.gae.centroids.cpu().detach().numpy()

visualize_umap(
    0,
    encoded,
    point_color=clusters,
    cluster_centers=centroids
)

# visualize_tsne(0, encoded, color=true_labels, centroids=centroids)
# visualize_tsne(0, encoded, color=soft_assignments.argmax(axis=1), centroids=centroids)
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
soft_assignments
# Out:
# tensor([[0.0000, 0.1723, 0.1086, 0.4896, 0.0397, 0.1898],
#         [0.0000, 0.1678, 0.1074, 0.4892, 0.0456, 0.1900],
#         [0.0000, 0.1663, 0.1095, 0.4918, 0.0420, 0.1905],
#         ...,
#         [0.0022, 0.3321, 0.2949, 0.0971, 0.2736, 0.0000],
#         [0.0022, 0.3321, 0.2949, 0.0971, 0.2736, 0.0000],
#         [0.0031, 0.3275, 0.2968, 0.0977, 0.2749, 0.0000]],
#        grad_fn=<DivBackward0>)

# %%
model_copy=copy.deepcopy(model)

# %%
model_copy
# Out:
# WrcfGAE(
#   (gae): GraphAutoEncoder(
#     (encoder_layer): SparseGraphConvolution()
#   )
#   (wrcf): WRCFLayer()
# )

# %%
def retrain_with_topo(gae_model, ground_truth, adjacency_sparse, node_features):
    # Normalize adjacency
    adj_norm_tuple = normalize_adjacency(adjacency_sparse)
    adj_label_tuple = convert_sparse_matrix(adjacency_sparse)

    adj_norm = torch.sparse.FloatTensor(
        torch.LongTensor(adj_norm_tuple[0].T),
        torch.FloatTensor(adj_norm_tuple[1]),
        torch.Size(adj_norm_tuple[2])
    ).cpu()

    adj_label = torch.sparse.FloatTensor(
        torch.LongTensor(adj_label_tuple[0].T),
        torch.FloatTensor(adj_label_tuple[1]),
        torch.Size(adj_label_tuple[2])
    ).cpu()

    # Class imbalance handling
    pos_weight = float(
        adjacency_sparse.shape[0] * adjacency_sparse.shape[0] - adjacency_sparse.sum()
    ) / adjacency_sparse.sum()

    norm = (
        adjacency_sparse.shape[0] * adjacency_sparse.shape[0] /
        float((adjacency_sparse.shape[0] * adjacency_sparse.shape[0] - adjacency_sparse.sum()) * 2)
    )

    weight_mask = adj_label.to_dense().view(-1) == 1
    weight_tensor = torch.ones(weight_mask.size(0))
    weight_tensor[weight_mask] = pos_weight

    # === TOPO TRAINING WRAPPER ===
    topo_trainer = WrcfGAE(
        adjacency_sparse=adjacency_sparse,
        gae_model=gae_model,
        ground_truth=ground_truth
    )

    optimizer = torch.optim.Adam(topo_trainer.parameters(), lr=0.01)

    for epoch in range(100):
        optimizer.zero_grad()

        total_loss, _, _, _ = topo_trainer(
            node_features.cpu(),
            epoch,
            adj_label,
            weight_tensor,
            norm
        )

        total_loss.backward()
        optimizer.step()

    # 🔑 CRITICAL FIX:
    # Return the INNER GraphAutoEncoder, not WrcfGAE
    return topo_trainer.gae

# %%
# IMPORTANT: copy the *GraphAutoEncoder*, not WrcfGAE
model2 = copy.deepcopy(model.gae)

# Ground-truth soft assignments (computed from GAE)
with torch.no_grad():
    _, latent_gt, soft_assignments_gt = model2(node_features, 1000)

ground_truth = (soft_assignments_gt, adjacency_sparse)

# Topology-aware retraining
model2 = retrain_with_topo(
    gae_model=model2,                  # <-- GraphAutoEncoder ONLY
    ground_truth=ground_truth,
    adjacency_sparse=adjacency_sparse,
    node_features=node_features
)

# %%
plt.figure(figsize=(10, 10))
model2.eval()

with torch.no_grad():
    _, latent_embeddings, soft_assignments = model2(node_features, 1000)

encoded = latent_embeddings.cpu().detach().numpy()
centroids = model2.centroids.cpu().detach().numpy()

predicted_clusters = soft_assignments.argmax(dim=1).cpu().detach().numpy()

# UMAP with ground-truth communities
visualize_umap(
    0,
    encoded,
    point_color=clusters,
    cluster_centers=centroids
)

# UMAP with predicted clusters
visualize_umap(
    0,
    encoded,
    point_color=predicted_clusters,
    cluster_centers=centroids
)

# t-SNE with KMeans on latent space
kmeans_model = KMeans(n_clusters=args.n_cluster)
kmeans_model.fit(encoded)

visualize_tsne(
    0,
    encoded,
    point_color=kmeans_model.labels_,
    cluster_centers=centroids
)
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
run_kmeans_evaluation(
    latent_embeddings,
    true_labels=clusters,
    soft_assignments=soft_assignments,
    n_clusters=args.n_cluster
)
# Out:
# Purity 1.0
# Purity 0.98
